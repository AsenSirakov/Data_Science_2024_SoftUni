# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
coffee_data = pd.read_csv("Data/merged_data_cleaned.csv")

# %%
coffee_data
# Out:
#       Unnamed: 0  Species                     Owner Country.of.Origin  \
# 0              0  Arabica                 metad plc          Ethiopia
# 1              1  Arabica                 metad plc          Ethiopia
# 2              2  Arabica  grounds for health admin         Guatemala
# 3              3  Arabica       yidnekachew dabessa          Ethiopia
# 4              4  Arabica                 metad plc          Ethiopia
# ...          ...      ...                       ...               ...
# 1334        1334  Robusta               luis robles           Ecuador
# 1335        1335  Robusta               luis robles           Ecuador
# 1336        1336  Robusta               james moore     United States
# 1337        1337  Robusta             cafe politico             India
# 1338        1338  Robusta             cafe politico           Vietnam
#
#                                      Farm.Name Lot.Number            Mill  \
# ...

# %%
coffee_data.shape
# Out:
# (1339, 44)

# %%
coffee_data.columns
# Out:
# Index(['Unnamed: 0', 'Species', 'Owner', 'Country.of.Origin', 'Farm.Name',
#        'Lot.Number', 'Mill', 'ICO.Number', 'Company', 'Altitude', 'Region',
#        'Producer', 'Number.of.Bags', 'Bag.Weight', 'In.Country.Partner',
#        'Harvest.Year', 'Grading.Date', 'Owner.1', 'Variety',
#        'Processing.Method', 'Aroma', 'Flavor', 'Aftertaste', 'Acidity', 'Body',
#        'Balance', 'Uniformity', 'Clean.Cup', 'Sweetness', 'Cupper.Points',
#        'Total.Cup.Points', 'Moisture', 'Category.One.Defects', 'Quakers',
#        'Color', 'Category.Two.Defects', 'Expiration', 'Certification.Body',
#        'Certification.Address', 'Certification.Contact', 'unit_of_measurement',
#        'altitude_low_meters', 'altitude_high_meters', 'altitude_mean_meters'],
#       dtype='object')

# %%
coffee_data.dtypes
# Out:
# Unnamed: 0                 int64
# Species                   object
# Owner                     object
# Country.of.Origin         object
# Farm.Name                 object
# Lot.Number                object
# Mill                      object
# ICO.Number                object
# Company                   object
# Altitude                  object
# Region                    object
# Producer                  object
# Number.of.Bags             int64
# Bag.Weight                object
# In.Country.Partner        object
# Harvest.Year              object
# Grading.Date              object
# Owner.1                   object
# Variety                   object
# Processing.Method         object
# Aroma                    float64
# Flavor                   float64
# Aftertaste               float64
# Acidity                  float64
# Body                     float64
# Balance                  float64
# Uniformity               float64
# Clean.Cup                float64
# ...

# %%
coffee_data
# Out:
#       Unnamed: 0  Species                     Owner Country.of.Origin  \
# 0              0  Arabica                 metad plc          Ethiopia
# 1              1  Arabica                 metad plc          Ethiopia
# 2              2  Arabica  grounds for health admin         Guatemala
# 3              3  Arabica       yidnekachew dabessa          Ethiopia
# 4              4  Arabica                 metad plc          Ethiopia
# ...          ...      ...                       ...               ...
# 1334        1334  Robusta               luis robles           Ecuador
# 1335        1335  Robusta               luis robles           Ecuador
# 1336        1336  Robusta               james moore     United States
# 1337        1337  Robusta             cafe politico             India
# 1338        1338  Robusta             cafe politico           Vietnam
#
#                                      Farm.Name Lot.Number            Mill  \
# ...

# %%
def to_snake_case(column_name):
    return column_name.lower().replace('.', '_').replace(' ', '_')

coffee_data_converted_column_names = coffee_data.rename(columns=lambda col: to_snake_case(col))

# %%
coffee_data
# Out:
#       Unnamed: 0  Species                     Owner Country.of.Origin  \
# 0              0  Arabica                 metad plc          Ethiopia
# 1              1  Arabica                 metad plc          Ethiopia
# 2              2  Arabica  grounds for health admin         Guatemala
# 3              3  Arabica       yidnekachew dabessa          Ethiopia
# 4              4  Arabica                 metad plc          Ethiopia
# ...          ...      ...                       ...               ...
# 1334        1334  Robusta               luis robles           Ecuador
# 1335        1335  Robusta               luis robles           Ecuador
# 1336        1336  Robusta               james moore     United States
# 1337        1337  Robusta             cafe politico             India
# 1338        1338  Robusta             cafe politico           Vietnam
#
#                                      Farm.Name Lot.Number            Mill  \
# ...

# %%
coffee_data_converted_column_names
# Out:
#       unnamed:_0  species                     owner country_of_origin  \
# 0              0  Arabica                 metad plc          Ethiopia
# 1              1  Arabica                 metad plc          Ethiopia
# 2              2  Arabica  grounds for health admin         Guatemala
# 3              3  Arabica       yidnekachew dabessa          Ethiopia
# 4              4  Arabica                 metad plc          Ethiopia
# ...          ...      ...                       ...               ...
# 1334        1334  Robusta               luis robles           Ecuador
# 1335        1335  Robusta               luis robles           Ecuador
# 1336        1336  Robusta               james moore     United States
# 1337        1337  Robusta             cafe politico             India
# 1338        1338  Robusta             cafe politico           Vietnam
#
#                                      farm_name lot_number            mill  \
# ...

# %%
# Count occurrences of 'kg' and 'lbs' in the 'bag_weight' column
kg_count = coffee_data_converted_column_names['bag_weight'].str.contains('kg', case=False).sum()
lbs_count = coffee_data_converted_column_names['bag_weight'].str.contains('lbs', case=False).sum()

kg_count, lbs_count
# Out:
# (1198, 116)

# %%
coffee_data_converted_column_names.bag_weight.value_counts()
# Out:
# bag_weight
# 1 kg        331
# 60 kg       256
# 69 kg       200
# 70 kg       156
# 2 kg        122
# 100 lbs      59
# 30 kg        29
# 5 lbs        23
# 6            19
# 20 kg        14
# 50 kg        14
# 10 kg        11
# 59 kg        10
# 1 lbs         8
# 1             7
# 3 lbs         7
# 5 kg          7
# 2 lbs         5
# 4 lbs         4
# 80 kg         4
# 18975 kg      4
# 0 lbs         3
# 46 kg         3
# 29 kg         2
# 9000 kg       2
# 25 kg         2
# 66 kg         2
# 35 kg         2
# 12000 kg      2
# 40 kg         2
# 6 kg          2
# 19200 kg      2
# 15 kg         2
# 13800 kg      1
# 100 kg        1
# 55 lbs        1
# 4 kg          1
# 67 kg         1
# 350 kg        1
# 3 kg          1
# 8 kg          1
# 80 lbs        1
# 24 kg         1
# 1500 kg       1
# 2 kg,lbs      1
# 0 kg          1
# 660 kg        1
# 1218 kg       1
# 2             1
# 18 kg         1
# 150 lbs       1
# 18000 kg      1
# 1 kg,lbs      1
# 132 lbs       1
# ...

# %%
import pandas as pd

# Assuming 'coffee_data_converted_column_names' DataFrame is already loaded

# Count occurrences of 'kg' and 'lbs' in the 'bag_weight' column
kg_count = coffee_data_converted_column_names['bag_weight'].str.contains('kg', case=False).sum()
lbs_count = coffee_data_converted_column_names['bag_weight'].str.contains('lbs', case=False).sum()

print("Number of 'kg' entries:", kg_count)
print("Number of 'lbs' entries:", lbs_count)
# Out:
# Number of 'kg' entries: 1198
# Number of 'lbs' entries: 116

# %%
# Get summary statistics for 'bag_weight_kg'
summary_statistics = coffee_data_converted_column_names['bag_weight'].describe()

# Print summary statistics
print(summary_statistics)
# Out:
# count     1339
# unique      56
# top       1 kg
# freq       331
# Name: bag_weight, dtype: object

# %%
coffee_data_filtered_without_0_lbs = coffee_data_converted_column_names[coffee_data_converted_column_names['bag_weight'] != '0 lbs']

# %%
coffee_data_filtered
# Out:
#       unnamed:_0  species                     owner country_of_origin  \
# 0              0  Arabica                 metad plc          Ethiopia
# 1              1  Arabica                 metad plc          Ethiopia
# 2              2  Arabica  grounds for health admin         Guatemala
# 3              3  Arabica       yidnekachew dabessa          Ethiopia
# 4              4  Arabica                 metad plc          Ethiopia
# ...          ...      ...                       ...               ...
# 1334        1334  Robusta               luis robles           Ecuador
# 1335        1335  Robusta               luis robles           Ecuador
# 1336        1336  Robusta               james moore     United States
# 1337        1337  Robusta             cafe politico             India
# 1338        1338  Robusta             cafe politico           Vietnam
#
#                                      farm_name lot_number            mill  \
# ...

# %%
coffee_data_filtered.bag_weight.value_counts()
# Out:
# bag_weight
# 1 kg        331
# 60 kg       256
# 69 kg       200
# 70 kg       156
# 2 kg        122
# 100 lbs      59
# 30 kg        29
# 5 lbs        23
# 6            19
# 20 kg        14
# 50 kg        14
# 10 kg        11
# 59 kg        10
# 1 lbs         8
# 1             7
# 3 lbs         7
# 5 kg          7
# 2 lbs         5
# 4 lbs         4
# 80 kg         4
# 18975 kg      4
# 46 kg         3
# 29 kg         2
# 9000 kg       2
# 25 kg         2
# 66 kg         2
# 35 kg         2
# 12000 kg      2
# 40 kg         2
# 6 kg          2
# 19200 kg      2
# 15 kg         2
# 13800 kg      1
# 100 kg        1
# 55 lbs        1
# 4 kg          1
# 67 kg         1
# 350 kg        1
# 3 kg          1
# 8 kg          1
# 80 lbs        1
# 24 kg         1
# 1500 kg       1
# 2 kg,lbs      1
# 0 kg          1
# 660 kg        1
# 1218 kg       1
# 2             1
# 18 kg         1
# 150 lbs       1
# 18000 kg      1
# 1 kg,lbs      1
# 132 lbs       1
# 34 kg         1
# ...
